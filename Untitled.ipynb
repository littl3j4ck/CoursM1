# %%
import math as mth
import numpy as np
import matplotlib.pyplot as plt

# %%
def J(theta_I):
    return (theta_I+1)**2
print(J(4))
# Out:
# 25

# %%
theta = list(np.arange(-10,10,0.01))

# %%
J_theta=[J(i) for i in theta]
plt.plot(theta,J_theta)

# %%
def dJ_dtheta(x_i):
    return 2*(x_i+1)
print(dJ_dtheta(-1))
# Out:
# 0

# %%
dJ_theta=[dJ_dtheta(i) for i in theta]
plt.plot(theta,dJ_theta)

# %%
def gradient_descent(theta_0, lr, nb_iters, dJ_dtheta):
    thetaN=theta_0
    for t in range(nb_iters):
        thetaN=thetaN-lr*dJ_dtheta(thetaN)
        plt.plot(thetaN,J(thetaN),marker='o',markersize=3,color='red')
    return thetaN
Gradient=(gradient_descent(-7,0.1,1000,dJ_dtheta))

# %%
Gradient=(gradient_descent(-8,0.1,1000,dJ_dtheta))
Gradient
# Out:
# -1.0000000000000004

# %%
Gradient=(gradient_descent(7,0.1,1000,dJ_dtheta))
Gradient
# Out:
# -0.9999999999999998

# %%
Gradient=(gradient_descent(-7,0.998,1000,dJ_dtheta))
Gradient
# Out:
# -1.109015857213537

# %%
list_x= list(np.random.uniform(20,40,100))
print (list_x)
# Out:
# [32.30579045022157, 37.19457736411002, 38.714710994983264, 35.649188192705324, 20.43460421433205, 29.66803834893935, 31.46230436454119, 34.04447587184496, 33.990496658428846, 30.583170151089444, 21.376332848695043, 25.733088178679466, 30.598968316586507, 34.979145601005655, 30.908432628286732, 34.33904837656016, 22.467750309308016, 29.75507653123115, 33.414584553780756, 34.231456950084805, 36.47830534855673, 33.41163822989787, 21.885501303887505, 35.82306605326934, 29.58759257466027, 26.107333929806813, 37.877145754086804, 24.924495844687137, 26.725710024743325, 39.316974248370876, 36.8182393981954, 28.294380553914394, 23.617874315053776, 31.201374010196382, 23.25780552333061, 29.96020681306872, 34.393875823498135, 32.34052688561788, 32.35624421819438, 28.747058107314956, 20.803414999564847, 27.999902751967117, 22.824611475176113, 28.52779242719366, 26.850649902836707, 38.26305442020712, 30.22297090640993, 37.49793672905264, 38.770288452033355, 38.77411537745578, 34.65112537707972, 2
# ...

# %%
list_y = [1.5*5+i+np.random.normal(0.1) for i in list_x]
print (list_y)
# Out:
# [38.59562025587209, 43.85231642826455, 46.38871541495496, 44.0907077617826, 29.778700060571495, 37.48479883056693, 40.59658163457499, 41.01182740423926, 41.57444244271308, 39.315158780006904, 27.162445467458873, 33.13523627866197, 37.62511272824199, 43.08162764128834, 37.65265764616594, 39.53809357052557, 30.98964708632573, 39.12828566585666, 41.63987194748118, 41.691567558989995, 43.45734727294373, 40.736059464442825, 28.877455881201122, 43.469868838580176, 37.70335127406453, 32.632205924896695, 45.257504198067004, 31.62489057105755, 34.45579369452002, 47.29558975286291, 44.13098731794837, 37.481079980747275, 32.42684760004743, 38.46551369678579, 30.76244748888478, 36.24368042358184, 42.189032087535665, 39.30979623644743, 40.10595302978804, 36.16739612799711, 27.9887025821198, 34.657770677608745, 31.358598680144166, 33.8818560368591, 34.28156592105447, 45.18367168607738, 36.92014719488754, 43.489729024537155, 47.290510333283294, 47.58717093388062, 42.49316029043346, 36.5502349991626
# ...

# %%
plt.scatter(list_x,list_y)

# %%
Y =np.asarray(list_y)
xt= np.transpose(X)
product = np.dot(Xt,X)
theInverse= np.linalg.inv(product)
Beta= np.dot(np.dot(theInverse,Xt),Y)
b_cf, w_cf= Beta[0],Beta[1]

# %%
def scaler (x,y,w,b):
    return ((w*x)+b-y)**2
print(scaler(1,3,1,2))
# Out:
# 0

# %%
def dl_dw (x_i,y_i,w,b):
    return -2 * x_i*(y_i - (w*x_i+b))
print(dl_dw(4,-1,0,0))
# Out:
# 8

# %%
def dl_db(x_i,y_i,w,b):
    return -2*(y_i - (w*x_i+b))
print(dl_db(3,3,0,0))
# Out:
# -6
# 100
# 100

# %%
def update_w_and_b (x,y,w,b,lr):
    grad_w=0
    grad_b=0
    for i in range(len(Y)):
        grad_w += dl_bw(x[i],y[i],w,b)
        grad_b += dl_db(x[i], y [i], w,b)
    w -= (1 / float(N)) * grad_w * lr
    y -= (1/float(N)) * grab_b * lr
    return w, b
from sklearn.lnear_model import LinearRegression
model = linearRegression().fit(np.asarray(x).reshape
