# %%
import pandas as pd

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep ='|',index_col='user_id')

# %%
users.head(10)
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 943 entries, 1 to 943
# Data columns (total 4 columns):
# age           943 non-null int64
# gender        943 non-null object
# occupation    943 non-null object
# zip_code      943 non-null object
# dtypes: int64(1), object(3)
# memory usage: 36.8+ KB

# %%
agemoyen=users.groupby('occupation').age.mean()

# %%
agemoyen.sort_values(ascending=False)
# Out:
# occupation
# retired          63.071429
# doctor           43.571429
# educator         42.010526
# healthcare       41.562500
# librarian        40.000000
# administrator    38.746835
# executive        38.718750
# marketing        37.615385
# lawyer           36.750000
# engineer         36.388060
# writer           36.311111
# salesman         35.666667
# scientist        35.548387
# other            34.523810
# technician       33.148148
# programmer       33.121212
# homemaker        32.571429
# artist           31.392857
# entertainment    29.222222
# none             26.555556
# student          22.081633
# Name: age, dtype: float64

# %%
def gender_to_numeric(x):
    if x=="M":
        return 1
    if x=="F":
        return 0

# %%
users['gender_num'] = users['gender'].apply(gender_to_numeric)

# %%
users.head()
# Out:
#          age gender  occupation zip_code  gender_num
# user_id
# 1         24      M  technician    85711           1
# 2         53      F       other    94043           0
# 3         23      M      writer    32067           1
# 4         24      M  technician    43537           1
# 5         33      F       other    15213           0

# %%
phomme=users.groupby('occupation').gender_n.sum() / users.occupation.value.counts() * 100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e1ac931ab0f4> in <module>()
# ----> 1 phomme=users.groupby('occupation').gender_n.sum() / users.occupation.value.counts() * 100
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'gender_n'

# %%
phomme.sort_values(ascending= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-39c9f4b6ac67> in <module>()
# ----> 1 phomme.sort_values(ascending= False)
#
# NameError: name 'phomme' is not defined

# %%
users.groupby('occupation').age.agg(['min','mean','max'])
# Out:
#                min       mean  max
# occupation
# administrator   21  38.746835   70
# artist          19  31.392857   48
# doctor          28  43.571429   64
# educator        23  42.010526   63
# engineer        22  36.388060   70
# entertainment   15  29.222222   50
# executive       22  38.718750   69
# healthcare      22  41.562500   62
# homemaker       20  32.571429   50
# lawyer          21  36.750000   53
# librarian       23  40.000000   69
# marketing       24  37.615385   55
# none            11  26.555556   55
# other           13  34.523810   64
# programmer      20  33.121212   63
# retired         51  63.071429   73
# salesman        18  35.666667   66
# scientist       23  35.548387   55
# student          7  22.081633   42
# technician      21  33.148148   55
# writer          18  36.311111   60

# %%
pd.isnull(users).sum()

# %%
import numpy as np

# %%
users.iloc[10:30,2:3] = np.nan

# %%
users.head(40)
# Out:
#          age gender     occupation zip_code  gender_num
# user_id
# 1         24      M     technician    85711           1
# 2         53      F          other    94043           0
# 3         23      M         writer    32067           1
# 4         24      M     technician    43537           1
# 5         33      F          other    15213           0
# 6         42      M      executive    98101           1
# 7         57      M  administrator    91344           1
# 8         36      M  administrator    05201           1
# 9         29      M        student    01002           1
# 10        53      M         lawyer    90703           1
# 11        39      F            NaN    30329           0
# 12        28      F            NaN    06405           0
# 13        47      M            NaN    29206           1
# 14        45      M            NaN    55106           1
# 15        49      F            NaN    97301           0
# 16        21      M            NaN    10309           1
# ...

# %%
users.occupation.fillna('?',inplace= True)

# %%
del users['zip_code']

# %%
users.iloc[0:3,:]= np.nan

# %%
users = users.dropna(how='any')

# %%
users = users.reset_index(drop=True)
users.head(10)
# Out:
#     age gender     occupation  gender_num
# 0  24.0      M     technician         1.0
# 1  33.0      F          other         0.0
# 2  42.0      M      executive         1.0
# 3  57.0      M  administrator         1.0
# 4  36.0      M  administrator         1.0
# 5  29.0      M        student         1.0
# 6  53.0      M         lawyer         1.0
# 7  39.0      F              ?         0.0
# 8  28.0      F              ?         0.0
# 9  47.0      M              ?         1.0
