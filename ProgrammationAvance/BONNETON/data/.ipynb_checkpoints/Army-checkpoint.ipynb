# %%
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
army = pd.DataFrame(raw_data, columns = ['regiment', 'compagny', 'deaths', 'battles', 'size', 'veterans', 'readiness', 'armored','deserters','origin'])

# %%
army = army.set_index('origin')
army
# Out:
#               regiment compagny  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks      NaN     523        5  1045         1          1
# California  Nighthawks      NaN      52       42   957         5          2
# Texas       Nighthawks      NaN      25        2  1099        62          3
# Florida     Nighthawks      NaN     616        2  1400        26          3
# Maine         Dragoons      NaN      43        4  1592        73          2
# Iowa          Dragoons      NaN     234        7  1006        37          1
# Alaska        Dragoons      NaN     523        8   987       949          2
# Washington    Dragoons      NaN      62        3   849        48          3
# Oregon          Scouts      NaN      62        4   973        48          2
# Wyoming         Scouts      NaN      73        7  1005       435          1
# Louisana        Scouts      NaN      37        8  1099        63          2
# Georgia         Scouts      NaN      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %%
ar=army.loc[['Maine','Alaska'], ["deaths","size","deserters"]]
ar
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
army.iloc[3:7]
# Out:
#            regiment compagny  deaths  battles  size  veterans  readiness  \
# origin
# Florida  Nighthawks      NaN     616        2  1400        26          3
# Maine      Dragoons      NaN      43        4  1592        73          2
# Iowa       Dragoons      NaN     234        7  1006        37          1
# Alaska     Dragoons      NaN     523        8   987       949          2
#
#          armored  deserters
# origin
# Florida        1          2
# Maine          0          3
# Iowa           1          4
# Alaska         0         24

# %%
army[army['deaths']> 50]
# Out:
#               regiment compagny  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks      NaN     523        5  1045         1          1
# California  Nighthawks      NaN      52       42   957         5          2
# Florida     Nighthawks      NaN     616        2  1400        26          3
# Iowa          Dragoons      NaN     234        7  1006        37          1
# Alaska        Dragoons      NaN     523        8   987       949          2
# Washington    Dragoons      NaN      62        3   849        48          3
# Oregon          Scouts      NaN      62        4   973        48          2
# Wyoming         Scouts      NaN      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3

# %%
army[(army['deaths'] > 500) | (army['deaths'] < 50)]
# Out:
#             regiment compagny  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks      NaN     523        5  1045         1          1
# Texas     Nighthawks      NaN      25        2  1099        62          3
# Florida   Nighthawks      NaN     616        2  1400        26          3
# Maine       Dragoons      NaN      43        4  1592        73          2
# Alaska      Dragoons      NaN     523        8   987       949          2
# Louisana      Scouts      NaN      37        8  1099        63          2
# Georgia       Scouts      NaN      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %%
army(army['regiment'] != ['Dragoons'])
# Out:
#   File "<ipython-input-14-9dbbcb645545>", line 1
#     army(army['regiment'] !: ['Dragoons'])
#                           ^
# SyntaxError: invalid syntax

# %%
army.groupby('regiment').mean()
# Out:
#             deaths  battles     size  veterans  readiness  armored  deserters
# regiment
# Dragoons    215.50     5.50  1108.50    276.75       2.00     0.50      15.50
# Nighthawks  304.00    12.75  1125.25     23.50       2.25     0.75      15.25
# Scouts       51.75     7.00  1150.00    222.75       2.00     0.50       2.50
